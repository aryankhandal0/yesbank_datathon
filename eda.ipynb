# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('Yes_Bank_Train.csv')

# %%
train.describe()
# Out:
#        Serial Number  total_net_assets  net_annual_expenses_ratio  \
# count   17773.000000      1.777300e+04               17761.000000
# mean     8887.000000      2.437201e+09                   1.022543
# std      5130.767503      1.014974e+10                   0.626989
# min         1.000000      5.000000e+03                   0.000000
# 25%      4444.000000      6.753000e+07                   0.620000
# 50%      8887.000000      3.325600e+08                   0.960000
# 75%     13330.000000      1.380000e+09                   1.370000
# max     17773.000000      1.880000e+11                  19.100000
#
#        morningstar_rating  portfolio_cash  portfolio_stocks  portfolio_bonds  \
# count        17773.000000    17768.000000      17768.000000     17768.000000
# mean             2.734822        6.950042         59.097221        30.481821
# std              1.368006       11.962977         42.187298        38.818028
# ...
